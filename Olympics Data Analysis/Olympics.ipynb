# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **header=1 -** It converts 1st row as a title

# %%
df = pd.read_csv('/content/olympics.csv', header=1)
df
# Out:
#                                        Unnamed: 0  ? Summer  01 !  02 !  03 !  \
# 0                               Afghanistan (AFG)        13     0     0     2
# 1                                   Algeria (ALG)        12     5     2     8
# 2                                 Argentina (ARG)        23    18    24    28
# 3                                   Armenia (ARM)         5     1     2     9
# 4                         Australasia (ANZ) [ANZ]         2     3     4     5
# ..                                            ...       ...   ...   ...   ...
# 142  Independent Olympic Participants (IOP) [IOP]         1     0     1     2
# 143                            Zambia (ZAM) [ZAM]        12     0     1     1
# 144                          Zimbabwe (ZIM) [ZIM]        12     3     4     1
# 145                        Mixed team (ZZX) [ZZX]         3     8     5     4
# 146                                        Totals        27  4809  4775  5130
#
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', '? Summer', '01 !', '02 !', '03 !', 'Total', '? Winter',
#        '01 !.1', '02 !.1', '03 !.1', 'Total.1', '? Games', '01 !.2', '02 !.2',
#        '03 !.2', 'Combined total'],
#       dtype='object')

# %%
new_names = {'Unnamed: 0' : 'Country',
             '? Summer' : 'Summer Olympics',
             '01 !': 'Gold',
             '02 !': 'Silver',
             '03 !': 'Bronze',
             '? Winter': 'Winter Olympics',
             '01 !.1': 'Gold.1',
             '02 !.1': 'Silver.1',
             '03 !.1': 'Bronze.1',
             '? Games': 'Games',
             '01 !.2': 'Gold.2',
             '02 !.2': 'Silver.2',
             '03 !.2': 'Bronze.2'
             }

# %%
df.rename(columns=new_names, inplace=True)
df
# Out:
#                                           Country  Summer Olympics  Gold  \
# 0                               Afghanistan (AFG)               13     0
# 1                                   Algeria (ALG)               12     5
# 2                                 Argentina (ARG)               23    18
# 3                                   Armenia (ARM)                5     1
# 4                         Australasia (ANZ) [ANZ]                2     3
# ..                                            ...              ...   ...
# 142  Independent Olympic Participants (IOP) [IOP]                1     0
# 143                            Zambia (ZAM) [ZAM]               12     0
# 144                          Zimbabwe (ZIM) [ZIM]               12     3
# 145                        Mixed team (ZZX) [ZZX]                3     8
# 146                                        Totals               27  4809
#
#      Silver  Bronze  Total  Winter Olympics  Gold.1  Silver.1  Bronze.1  \
# ...

# %% [markdown]
# ## Summarize Data

# %%
df[['Country', 'Total']].value_counts()
# Out:
# Country               Total
# Afghanistan (AFG)     2        1
# Singapore (SIN)       4        1
# Pakistan (PAK)        10       1
# Panama (PAN)          3        1
# Paraguay (PAR)        1        1
#                               ..
# Grenada (GRN)         1        1
# Guatemala (GUA)       1        1
# Guyana (GUY) [GUY]    1        1
# Haiti (HAI) [J]       2        1
# Zimbabwe (ZIM) [ZIM]  8        1
# Name: count, Length: 147, dtype: int64

# %%
len(df)
# Out:
# 147

# %%
df.shape
# Out:
# (147, 16)

# %%
df['Gold'].nunique()
# Out:
# 54

# %%
df.describe()
# Out:
#        Summer Olympics         Gold       Silver       Bronze         Total  \
# count       147.000000   147.000000   147.000000   147.000000    147.000000
# mean         13.476190    65.428571    64.965986    69.795918    200.190476
# std           7.072359   405.549990   399.309960   427.187344   1231.306297
# min           1.000000     0.000000     0.000000     0.000000      0.000000
# 25%           8.000000     0.000000     1.000000     1.000000      2.000000
# 50%          13.000000     3.000000     4.000000     6.000000     12.000000
# 75%          18.500000    24.000000    28.000000    29.000000     86.000000
# max          27.000000  4809.000000  4775.000000  5130.000000  14714.000000
#
#        Winter Olympics      Gold.1    Silver.1    Bronze.1      Total.1  \
# count       147.000000  147.000000  147.000000  147.000000   147.000000
# mean          6.700680   13.047619   13.034014   12.897959    38.979592
# ...

# %%
df.plot.hist(column='Combined total')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot.scatter(x='Gold', y='Total')
# Out:
# <Axes: xlabel='Gold', ylabel='Total'>
